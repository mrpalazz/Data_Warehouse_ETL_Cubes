# %% [markdown]
# # Exercise 02 -  OLAP Cubes - Grouping Sets

# %% [markdown]
# All the databases table in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](http://archive.oreilly.com/oreillyschool/courses/dba3/index.html)
#
# Start by connecting to the database by running the cells below. If you are coming back to this exercise, then uncomment and run the first cell to recreate the database. If you recently completed the slicing and dicing exercise, then skip to the second cell.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-star.sql
# Out:
# createdb: database creation failed: ERROR:  database "pagila_star" already exists
#  set_config
# ------------
#
# (1 row)
#
# psql:Data/pagila-star.sql:42: ERROR:  type "mpaa_rating" already exists
# psql:Data/pagila-star.sql:52: ERROR:  type "year" already exists
# psql:Data/pagila-star.sql:69: ERROR:  function "_group_concat" already exists with same argument types
# psql:Data/pagila-star.sql:86: ERROR:  function "film_in_stock" already exists with same argument types
# psql:Data/pagila-star.sql:103: ERROR:  function "film_not_in_stock" already exists with same argument types
# psql:Data/pagila-star.sql:148: ERROR:  function "get_customer_balance" already exists with same argument types
# psql:Data/pagila-star.sql:170: ERROR:  function "inventory_held_by_customer" already exists with same argument types
# psql:Data/pagila-star.sql:207: ERROR:  function "inventory_in_stock" already exists with same argument types
# psql:Data/pagila-star.sql:225: ERROR:  function "last_day" already exists with same argument types
# psql:Data/pagila-star.sql:240: ERROR:  function "last_updated" already exists with same argument types
# psql:Data/pagila-star.sql:264: ERROR:  relation "customer" already exists
# psql:Data/pagila-star.sql:328: ERROR:  function "rewards_report" already exists with same argument types
# psql:Data/pagila-star.sql:340: ERROR:  function "group_concat" already exists with same argument types
# psql:Data/pagila-star.sql:354: ERROR:  relation "actor_actor_id_seq" already exists
# psql:Data/pagila-star.sql:368: ERROR:  relation "actor" already exists
# psql:Data/pagila-star.sql:382: ERROR:  relation "category_category_id_seq" already exists
# psql:Data/pagila-star.sql:395: ERROR:  relation "category" already exists
# psql:Data/pagila-star.sql:409: ERROR:  relation "film_film_id_seq" already exists
# psql:Data/pagila-star.sql:433: ERROR:  relation "film" already exists
# psql:Data/pagila-star.sql:446: ERROR:  relation "film_actor" already exists
# psql:Data/pagila-star.sql:459: ERROR:  relation "film_category" already exists
# psql:Data/pagila-star.sql:482: ERROR:  relation "actor_info" already exists
# psql:Data/pagila-star.sql:496: ERROR:  relation "address_address_id_seq" already exists
# psql:Data/pagila-star.sql:514: ERROR:  relation "address" already exists
# psql:Data/pagila-star.sql:528: ERROR:  relation "city_city_id_seq" already exists
# psql:Data/pagila-star.sql:542: ERROR:  relation "city" already exists
# psql:Data/pagila-star.sql:556: ERROR:  relation "country_country_id_seq" already exists
# psql:Data/pagila-star.sql:569: ERROR:  relation "country" already exists
# psql:Data/pagila-star.sql:583: ERROR:  relation "customer_customer_id_seq" already exists
# psql:Data/pagila-star.sql:597: ERROR:  relation "customer_customer_id_seq1" already exists
# psql:Data/pagila-star.sql:629: ERROR:  relation "customer_list" already exists
# psql:Data/pagila-star.sql:655: ERROR:  relation "dimcustomer" already exists
# psql:Data/pagila-star.sql:669: ERROR:  relation "dimcustomer_customer_key_seq" already exists
# psql:Data/pagila-star.sql:694: ERROR:  relation "dimdate" already exists
# psql:Data/pagila-star.sql:715: ERROR:  relation "dimmovie" already exists
# psql:Data/pagila-star.sql:729: ERROR:  relation "dimmovie_movie_key_seq" already exists
# psql:Data/pagila-star.sql:758: ERROR:  relation "dimstore" already exists
# psql:Data/pagila-star.sql:772: ERROR:  relation "dimstore_store_key_seq" already exists
# psql:Data/pagila-star.sql:795: ERROR:  relation "factsales" already exists
# psql:Data/pagila-star.sql:809: ERROR:  relation "factsales_sales_key_seq" already exists
# psql:Data/pagila-star.sql:839: ERROR:  relation "film_list" already exists
# psql:Data/pagila-star.sql:853: ERROR:  relation "inventory_inventory_id_seq" already exists
# psql:Data/pagila-star.sql:867: ERROR:  relation "inventory" already exists
# psql:Data/pagila-star.sql:881: ERROR:  relation "language_language_id_seq" already exists
# psql:Data/pagila-star.sql:894: ERROR:  relation "language" already exists
# psql:Data/pagila-star.sql:917: ERROR:  relation "nicer_but_slower_film_list" already exists
# psql:Data/pagila-star.sql:931: ERROR:  relation "payment_payment_id_seq" already exists
# psql:Data/pagila-star.sql:947: ERROR:  relation "payment" already exists
# psql:Data/pagila-star.sql:961: ERROR:  relation "rental_rental_id_seq" already exists
# psql:Data/pagila-star.sql:978: ERROR:  relation "rental" already exists
# psql:Data/pagila-star.sql:997: ERROR:  relation "sales_by_film_category" already exists
# psql:Data/pagila-star.sql:1011: ERROR:  relation "staff_staff_id_seq" already exists
# psql:Data/pagila-star.sql:1032: ERROR:  relation "staff" already exists
# psql:Data/pagila-star.sql:1046: ERROR:  relation "store_store_id_seq" already exists
# psql:Data/pagila-star.sql:1060: ERROR:  relation "store" already exists
# psql:Data/pagila-star.sql:1082: ERROR:  relation "sales_by_store" already exists
# psql:Data/pagila-star.sql:1103: ERROR:  relation "staff_list" already exists
# psql:Data/pagila-star.sql:1348: ERROR:  duplicate key value violates unique constraint "actor_pkey"
# DETAIL:  Key (actor_id)=(1) already exists.
# CONTEXT:  COPY actor, line 1
#  setval
# --------
#     200
# (1 row)
#
# psql:Data/pagila-star.sql:1966: ERROR:  duplicate key value violates unique constraint "address_pkey"
# DETAIL:  Key (address_id)=(1) already exists.
# CONTEXT:  COPY address, line 1
#  setval
# --------
#     605
# (1 row)
#
# psql:Data/pagila-star.sql:1997: ERROR:  duplicate key value violates unique constraint "category_pkey"
# DETAIL:  Key (category_id)=(1) already exists.
# CONTEXT:  COPY category, line 1
#  setval
# --------
#      16
# (1 row)
#
# psql:Data/pagila-star.sql:2612: ERROR:  duplicate key value violates unique constraint "city_pkey"
# DETAIL:  Key (city_id)=(1) already exists.
# CONTEXT:  COPY city, line 1
#  setval
# --------
#     600
# (1 row)
#
# psql:Data/pagila-star.sql:2736: ERROR:  duplicate key value violates unique constraint "country_pkey"
# DETAIL:  Key (country_id)=(1) already exists.
# CONTEXT:  COPY country, line 1
#  setval
# --------
#     109
# (1 row)
#
# psql:Data/pagila-star.sql:3350: ERROR:  duplicate key value violates unique constraint "customer_pkey"
# DETAIL:  Key (customer_id)=(1) already exists.
# CONTEXT:  COPY customer, line 1
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
# psql:Data/pagila-star.sql:3971: ERROR:  duplicate key value violates unique constraint "dimcustomer_pkey"
# DETAIL:  Key (customer_key)=(1) already exists.
# CONTEXT:  COPY dimcustomer, line 1
#  setval
# --------
#       1
# (1 row)
#
# psql:Data/pagila-star.sql:4026: ERROR:  duplicate key value violates unique constraint "dimdate_pkey"
# DETAIL:  Key (date_key)=(20170407) already exists.
# CONTEXT:  COPY dimdate, line 1
# psql:Data/pagila-star.sql:5034: ERROR:  duplicate key value violates unique constraint "dimmovie_pkey"
# DETAIL:  Key (movie_key)=(1) already exists.
# CONTEXT:  COPY dimmovie, line 1
#  setval
# --------
#       1
# (1 row)
#
# psql:Data/pagila-star.sql:5051: ERROR:  duplicate key value violates unique constraint "dimstore_pkey"
# DETAIL:  Key (store_key)=(1) already exists.
# CONTEXT:  COPY dimstore, line 1
#  setval
# --------
#       1
# (1 row)
#
# psql:Data/pagila-star.sql:37164: ERROR:  duplicate key value violates unique constraint "factsales_pkey"
# DETAIL:  Key (sales_key)=(1) already exists.
# CONTEXT:  COPY factsales, line 1
#  setval
# --------
#   32098
# (1 row)
#
# psql:Data/pagila-star.sql:38179: ERROR:  duplicate key value violates unique constraint "film_pkey"
# DETAIL:  Key (film_id)=(1) already exists.
# CONTEXT:  COPY film, line 1: "1	ACADEMY DINOSAUR	A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The C..."
# psql:Data/pagila-star.sql:43649: ERROR:  duplicate key value violates unique constraint "film_actor_pkey"
# DETAIL:  Key (actor_id, film_id)=(1, 1) already exists.
# CONTEXT:  COPY film_actor, line 1
# psql:Data/pagila-star.sql:44657: ERROR:  duplicate key value violates unique constraint "film_category_pkey"
# DETAIL:  Key (film_id, category_id)=(1, 6) already exists.
# CONTEXT:  COPY film_category, line 1
#  setval
# --------
#    1000
# (1 row)
#
# psql:Data/pagila-star.sql:49253: ERROR:  duplicate key value violates unique constraint "inventory_pkey"
# DETAIL:  Key (inventory_id)=(1) already exists.
# CONTEXT:  COPY inventory, line 1
#  setval
# --------
#    4581
# (1 row)
#
# psql:Data/pagila-star.sql:49274: ERROR:  duplicate key value violates unique constraint "language_pkey"
# DETAIL:  Key (language_id)=(1) already exists.
# CONTEXT:  COPY language, line 1
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
# psql:Data/pagila-star.sql:97446: ERROR:  duplicate key value violates unique constraint "rental_pkey"
# DETAIL:  Key (rental_id)=(2) already exists.
# CONTEXT:  COPY rental, line 1
#  setval
# --------
#   16049
# (1 row)
#
# psql:Data/pagila-star.sql:97463: ERROR:  duplicate key value violates unique constraint "staff_pkey"
# DETAIL:  Key (staff_id)=(1) already exists.
# CONTEXT:  COPY staff, line 1
#  setval
# --------
#       2
# (1 row)
#
# psql:Data/pagila-star.sql:97480: ERROR:  duplicate key value violates unique constraint "store_pkey"
# DETAIL:  Key (store_id)=(1) already exists.
# CONTEXT:  COPY store, line 1
#  setval
# --------
#       2
# (1 row)
#
# psql:Data/pagila-star.sql:97495: ERROR:  multiple primary keys for table "actor" are not allowed
# psql:Data/pagila-star.sql:97503: ERROR:  multiple primary keys for table "address" are not allowed
# psql:Data/pagila-star.sql:97511: ERROR:  multiple primary keys for table "category" are not allowed
# psql:Data/pagila-star.sql:97519: ERROR:  multiple primary keys for table "city" are not allowed
# psql:Data/pagila-star.sql:97527: ERROR:  multiple primary keys for table "country" are not allowed
# psql:Data/pagila-star.sql:97535: ERROR:  multiple primary keys for table "customer" are not allowed
# psql:Data/pagila-star.sql:97543: ERROR:  multiple primary keys for table "dimcustomer" are not allowed
# psql:Data/pagila-star.sql:97551: ERROR:  multiple primary keys for table "dimdate" are not allowed
# psql:Data/pagila-star.sql:97559: ERROR:  multiple primary keys for table "dimmovie" are not allowed
# psql:Data/pagila-star.sql:97567: ERROR:  multiple primary keys for table "dimstore" are not allowed
# psql:Data/pagila-star.sql:97575: ERROR:  multiple primary keys for table "factsales" are not allowed
# psql:Data/pagila-star.sql:97583: ERROR:  multiple primary keys for table "film_actor" are not allowed
# psql:Data/pagila-star.sql:97591: ERROR:  multiple primary keys for table "film_category" are not allowed
# psql:Data/pagila-star.sql:97599: ERROR:  multiple primary keys for table "film" are not allowed
# psql:Data/pagila-star.sql:97607: ERROR:  multiple primary keys for table "inventory" are not allowed
# psql:Data/pagila-star.sql:97615: ERROR:  multiple primary keys for table "language" are not allowed
# psql:Data/pagila-star.sql:97623: ERROR:  multiple primary keys for table "rental" are not allowed
# psql:Data/pagila-star.sql:97631: ERROR:  multiple primary keys for table "staff" are not allowed
# psql:Data/pagila-star.sql:97639: ERROR:  multiple primary keys for table "store" are not allowed
# psql:Data/pagila-star.sql:97646: ERROR:  relation "film_fulltext_idx" already exists
# psql:Data/pagila-star.sql:97653: ERROR:  relation "idx_actor_last_name" already exists
# psql:Data/pagila-star.sql:97660: ERROR:  relation "idx_fk_address_id" already exists
# psql:Data/pagila-star.sql:97667: ERROR:  relation "idx_fk_city_id" already exists
# psql:Data/pagila-star.sql:97674: ERROR:  relation "idx_fk_country_id" already exists
# psql:Data/pagila-star.sql:97681: ERROR:  relation "idx_fk_customer_id" already exists
# psql:Data/pagila-star.sql:97688: ERROR:  relation "idx_fk_film_id" already exists
# psql:Data/pagila-star.sql:97695: ERROR:  relation "idx_fk_inventory_id" already exists
# psql:Data/pagila-star.sql:97702: ERROR:  relation "idx_fk_language_id" already exists
# psql:Data/pagila-star.sql:97709: ERROR:  relation "idx_fk_original_language_id" already exists
# psql:Data/pagila-star.sql:97716: ERROR:  relation "idx_fk_payment_customer_id" already exists
# psql:Data/pagila-star.sql:97723: ERROR:  relation "idx_fk_payment_staff_id" already exists
# psql:Data/pagila-star.sql:97730: ERROR:  relation "idx_fk_store_id" already exists
# psql:Data/pagila-star.sql:97737: ERROR:  relation "idx_last_name" already exists
# psql:Data/pagila-star.sql:97744: ERROR:  relation "idx_store_id_film_id" already exists
# psql:Data/pagila-star.sql:97751: ERROR:  relation "idx_title" already exists
# psql:Data/pagila-star.sql:97758: ERROR:  relation "idx_unq_manager_staff_id" already exists
# psql:Data/pagila-star.sql:97765: ERROR:  relation "idx_unq_rental_rental_date_inventory_id_customer_id" already exists
# psql:Data/pagila-star.sql:97772: ERROR:  trigger "film_fulltext_trigger" for relation "film" already exists
# psql:Data/pagila-star.sql:97779: ERROR:  trigger "last_updated" for relation "actor" already exists
# psql:Data/pagila-star.sql:97786: ERROR:  trigger "last_updated" for relation "address" already exists
# psql:Data/pagila-star.sql:97793: ERROR:  trigger "last_updated" for relation "category" already exists
# psql:Data/pagila-star.sql:97800: ERROR:  trigger "last_updated" for relation "city" already exists
# psql:Data/pagila-star.sql:97807: ERROR:  trigger "last_updated" for relation "country" already exists
# psql:Data/pagila-star.sql:97814: ERROR:  trigger "last_updated" for relation "customer" already exists
# psql:Data/pagila-star.sql:97821: ERROR:  trigger "last_updated" for relation "film" already exists
# psql:Data/pagila-star.sql:97828: ERROR:  trigger "last_updated" for relation "film_actor" already exists
# psql:Data/pagila-star.sql:97835: ERROR:  trigger "last_updated" for relation "film_category" already exists
# psql:Data/pagila-star.sql:97842: ERROR:  trigger "last_updated" for relation "inventory" already exists
# psql:Data/pagila-star.sql:97849: ERROR:  trigger "last_updated" for relation "language" already exists
# psql:Data/pagila-star.sql:97856: ERROR:  trigger "last_updated" for relation "rental" already exists
# psql:Data/pagila-star.sql:97863: ERROR:  trigger "last_updated" for relation "staff" already exists
# psql:Data/pagila-star.sql:97870: ERROR:  trigger "last_updated" for relation "store" already exists
# psql:Data/pagila-star.sql:97878: ERROR:  constraint "address_city_id_fkey" for relation "address" already exists
# psql:Data/pagila-star.sql:97886: ERROR:  constraint "city_country_id_fkey" for relation "city" already exists
# psql:Data/pagila-star.sql:97894: ERROR:  constraint "customer_address_id_fkey" for relation "customer" already exists
# psql:Data/pagila-star.sql:97902: ERROR:  constraint "customer_store_id_fkey" for relation "customer" already exists
# psql:Data/pagila-star.sql:97910: ERROR:  constraint "factsales_customer_key_fkey" for relation "factsales" already exists
# psql:Data/pagila-star.sql:97918: ERROR:  constraint "factsales_date_key_fkey" for relation "factsales" already exists
# psql:Data/pagila-star.sql:97926: ERROR:  constraint "factsales_movie_key_fkey" for relation "factsales" already exists
# psql:Data/pagila-star.sql:97934: ERROR:  constraint "factsales_store_key_fkey" for relation "factsales" already exists
# psql:Data/pagila-star.sql:97942: ERROR:  constraint "film_actor_actor_id_fkey" for relation "film_actor" already exists
# psql:Data/pagila-star.sql:97950: ERROR:  constraint "film_actor_film_id_fkey" for relation "film_actor" already exists
# psql:Data/pagila-star.sql:97958: ERROR:  constraint "film_category_category_id_fkey" for relation "film_category" already exists
# psql:Data/pagila-star.sql:97966: ERROR:  constraint "film_category_film_id_fkey" for relation "film_category" already exists
# psql:Data/pagila-star.sql:97974: ERROR:  constraint "film_language_id_fkey" for relation "film" already exists
# psql:Data/pagila-star.sql:97982: ERROR:  constraint "film_original_language_id_fkey" for relation "film" already exists
# psql:Data/pagila-star.sql:97990: ERROR:  constraint "inventory_film_id_fkey" for relation "inventory" already exists
# psql:Data/pagila-star.sql:97998: ERROR:  constraint "inventory_store_id_fkey" for relation "inventory" already exists
# psql:Data/pagila-star.sql:98006: ERROR:  constraint "payment_customer_id_fkey" for relation "payment" already exists
# psql:Data/pagila-star.sql:98014: ERROR:  constraint "payment_rental_id_fkey" for relation "payment" already exists
# psql:Data/pagila-star.sql:98022: ERROR:  constraint "payment_staff_id_fkey" for relation "payment" already exists
# psql:Data/pagila-star.sql:98030: ERROR:  constraint "rental_customer_id_fkey" for relation "rental" already exists
# psql:Data/pagila-star.sql:98038: ERROR:  constraint "rental_inventory_id_fkey" for relation "rental" already exists
# psql:Data/pagila-star.sql:98046: ERROR:  constraint "rental_staff_id_fkey" for relation "rental" already exists
# psql:Data/pagila-star.sql:98054: ERROR:  constraint "staff_address_id_fkey" for relation "staff" already exists
# psql:Data/pagila-star.sql:98062: ERROR:  constraint "staff_store_id_fkey" for relation "staff" already exists
# psql:Data/pagila-star.sql:98070: ERROR:  constraint "store_address_id_fkey" for relation "store" already exists

# %% [markdown]
# ### Connect to the local database where Pagila is loaded

# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ### Star Schema

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %% [markdown]
# # Grouping Sets
# - It happens often that for 3 dimensions, you want to aggregate a fact:
#     - by nothing (total)
#     - then by the 1st dimension
#     - then by the 2nd
#     - then by the 3rd
#     - then by the 1st and 2nd
#     - then by the 2nd and 3rd
#     - then by the 1st and 3rd
#     - then by the 1st and 2nd and 3rd
#
# - Since this is very common, and in all cases, we are iterating through all the fact table anyhow, there is a more clever way to do that using the SQL grouping statement "GROUPING SETS"

# %% [markdown]
# ## Total Revenue
#
# TODO: Write a query that calculates total revenue (sales_amount)

# %%
# %%sql
# SELECT ...
# FROM ...

# %% [markdown]
# ## Revenue by Country
# TODO: Write a query that calculates total revenue (sales_amount) by country

# %%
# %%sql
# SELECT ...
# FROM ...

# %% [markdown]
# ## Revenue by Month
# TODO: Write a query that calculates total revenue (sales_amount) by month

# %%
# %%sql
# SELECT ...
# FROM ...

# %% [markdown]
# ## Revenue by Month & Country
# TODO: Write a query that calculates total revenue (sales_amount) by month and country. Sort the data by month, country, and revenue in descending order. The first few rows of your output should match the table below.

# %%
# %%sql
# SELECT ...
# FROM ...

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Revenue Total, by Month, by Country, by Month & Country All in one shot
#
# TODO: Write a query that calculates total revenue at the various grouping levels done above (total, by month, by country, by month & country) all at once using the grouping sets function. Your output should match the table below.

# %%
# %%sql
# SELECT ...
# FROM ...

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>None</td>
#         <td>4824.43</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>None</td>
#         <td>9631.88</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Canada</td>
#         <td>11826.23</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>None</td>
#         <td>23886.56</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Australia</td>
#         <td>14136.07</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Canada</td>
#         <td>14423.39</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>None</td>
#         <td>28559.46</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Australia</td>
#         <td>271.08</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Canada</td>
#         <td>243.10</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>None</td>
#         <td>514.18</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>None</td>
#         <td>67416.51</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Australia</td>
#         <td>33726.77</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Canada</td>
#         <td>33689.74</td>
#     </tr>
# </tbody></table></div>
